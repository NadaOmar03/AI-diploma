# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    print(soup)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:11/23/2022
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3fc58ad4f070> in <cell line: 2>()
#       1 date=input("Please enter a date in the following formAT MM/DD/YYYY:")
# ----> 2 page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
#       3 def main(page):
#       4     src=page.content
#       5     soup= BeautifulSoup(src,"lxml")
#
# NameError: name 'requests' is not defined

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
import requests

# %%
import csv

# %%
from bs4 import BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    print(soup)

main(page)
# Out:
# Streaming output truncated to the last 5000 lines.
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/31/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks active" date="11/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                         23
#                     </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                 Wed
#             </div>
# </button>
# <button class="dayTabLinks" date="11/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/31/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/22/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/23/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/24/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/25/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/29/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/30/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="1/31/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>يناير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/22/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/23/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/24/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/25/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="2/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>فبراير</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>مارس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="3/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
# ...
#                     transform: translate3d(0, 100%, 0);
#                     visibility: visible
#                 }
#
#                 to {
#                     -webkit-transform: translateZ(0);
#                     transform: translateZ(0)
#                 }
#             }
#
#             @keyframes izootoSlideInDown {
#                 0% {
#                     -webkit-transform: translate3d(0, 100%, 0);
#                     transform: translate3d(0, 100%, 0);
#                     visibility: visible
#                 }
#
#                 to {
#                     -webkit-transform: translateZ(0);
#                     transform: translateZ(0)
#                 }
#             }
#
#             @-webkit-keyframes izootoSlideInUp {
#                 0% {
#                     -webkit-transform: translate3d(0, -100%, 0);
#                     transform: translate3d(0, -100%, 0);
#                     visibility: visible
#                 }
#
#                 to {
#                     -webkit-transform: translateZ(0);
#                     transform: translateZ(0)
#                 }
#             }
#
#             @keyframes izootoSlideInUp {
#                 0% {
#                     -webkit-transform: translate3d(0, -100%, 0);
#                     transform: translate3d(0, -100%, 0);
#                     visibility: visible
#                 }
#
#                 to {
#                     -webkit-transform: translateZ(0);
#                     transform: translateZ(0)
#                 }
#             }
#
#             #izooto-optin.izooto-optin--preview-container {
#                 position: fixed;
#                 z-index: 999999999;
#                 box-sizing: border-box;
#                 color: rgba(0, 0, 0, .87);
#                 font-family: droidLight, Arial
#             }
#
#             #izooto-optin.izooto-optin--sticky-header {
#                 width: 100%;
#                 bottom: 0;
#                 padding: 20px 0px 13px 0px;
#                 box-shadow: 0 2px 16px rgba(0, 0, 0, .1);
#                 background-color: #111111;
#                 webkit-animation-name: izootoSlideInDown;
#                 animation-name: izootoSlideInDown;
#                 webkit-animation-duration: .5s;
#                 animation-duration: .5s;
#                 -webkit-animation-fill-mode: none;
#                 animation-fill-mode: none
#             }
#
#             #izmiddle-box.hide #izooto-optin.izooto-optin--sticky-header {
#                 top: 100%;
#                 bottom: auto;
#                 webkit-animation-name: izootoSlideInUp;
#                 animation-name: izootoSlideInUp;
#                 webkit-animation-duration: .5s;
#                 animation-duration: .5s;
#             }
#
#             #izooto-optin-icon-content-container {
#                 margin: 0 15px;
#             }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--icon-wrapper {
#                 width: 50px;
#                 height: 50px
#             }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--icon-wrapper .izooto-optin--icon {
#                     max-height: 50px;
#                     margin-top: -3px
#                 }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--content {
#                 width: 100%;
#                 margin: 0 20px;
#             }
#
#             #izooto-optin .izooto-optin--content .izooto-optin--title span {
#                 color: #ffffff;
#                 font-size: 18px;
#                 word-break: break-word;
#                 font-weight: 400;
#                 font-family: droidLight, Arial;
#                 margin-bottom: 6px;
#             }
#
#             #izooto-optin .izooto-optin--content .izooto-optin--message span {
#                 color: #ffffffa6;
#                 font-size: 13px;
#                 font-weight: 400;
#                 font-family: droidLight, Arial
#             }
#
#             #izooto-optin .izooto-optin--ctas-container {
#                 margin: 0 10px;
#             }
#
#                 #izooto-optin .izooto-optin--ctas-container .izooto-optin--cta {
#                     margin: 0 5px;
#                     box-sizing: border-box;
#                     text-transform: unset;
#                     position: relative;
#                     -webkit-user-select: none;
#                     -moz-user-select: none;
#                     -ms-user-select: none;
#                     user-select: none;
#                     cursor: pointer;
#                     outline: 0;
#                     border: none;
#                     -webkit-tap-highlight-color: transparent;
#                     display: inline-block;
#                     white-space: nowrap;
#                     text-decoration: none;
#                     font-size: 13px;
#                     vertical-align: baseline;
#                     text-align: center;
#                     line-height: 36px;
#                     border-radius: 4px;
#                     padding: 0 13px;
#                     min-width: 100px;
#                     max-width: 175px;
#                     overflow: hidden;
#                     text-overflow: ellipsis;
#                     font-family: droidLight, Arial
#                 }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--ctas-container .izooto-optin--cta.izooto-optin--cta-later {
#                 background-color: #ffffff !important;
#                 color: #1d1d1d !important;
#             }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--ctas-container .izooto-optin--cta.izooto-optin--cta-allow {
#                 background-color: #0277bd !important;
#                 color: #ffffff !important;
#                 box-shadow: 0 3px 1px -2px rgba(0, 0, 0, .2), 0 2px 2px 0 rgba(0, 0, 0, .14), 0 1px 5px 0 rgba(0, 0, 0, .12)
#             }
#
#             #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper {
#                 position: absolute;
#                 width: auto;
#                 line-height: 1
#             }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper.izooto-optin--branding-wrapper-sticky-header {
#                     right: 5px;
#                     bottom: 3px
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper .izooto-optin--branding-text {
#                     text-decoration: none;
#                     font-size: 11px;
#                     font-weight: 400;
#                     font-family: droidLight, Arial;
#                     color: #fff
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper .izooto-optin--izooto-txt {
#                     color: #c2ccec
#                 }
#
#             @media screen and (max-width:640px) {
#                 #izooto-optin .iz-row--mobile-col {
#                     flex-direction: column
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--content {
#                     margin: 0 10px;
#                 }
#
#                 #izooto-optin .izooto-optin--content .izooto-optin--title span {
#                     font-size: 16px
#                 }
#
#                 #izooto-optin .izooto-optin--content .izooto-optin--message span {
#                     font-size: 13px;
#                     margin-top: 5px
#                 }
#
#                 #izooto-optin .izooto-optin--ctas-container-for-mob {
#                     margin-top: 15px;
#                     margin-bottom: 10px
#                 }
#
#                 #izooto-optin .izooto-optin--ctas-container .izooto-optin--cta {
#                     min-width: 85px;
#                     max-width: 50%
#                 }
#
#                 #izooto-optin.izooto-optin--sticky-header .izooto-optin--branding-wrapper.izooto-optin--branding-wrapper-sticky-header {
#                     right: 15.2px;
#                     bottom: 5px
#                 }
#             }
#         </style>
# <div class="izooto-optin--sticky-header izooto-optin--preview-container" dir="auto" id="izooto-optin">
# <div class="iz-row iz-row--space-btwn iz-row--mobile-col">
# <div class="iz-row iz-row--space-btwn" id="izooto-optin-icon-content-container">
# <div class="iz-col iz-col--content-center izooto-optin--icon-wrapper">
# <img alt="Default Opt-in Icon" class="izooto-optin--icon" height="40" src="https://cdnimg.izooto.com/icons/7/bell-icon.png" width="40"/>
# </div>
# <div class="izooto-optin--content">
# <div class="izooto-optin--title">
# <span class="izooto-optin--line-clamp izooto-optin--line-clamp-2">خدمة الإشعارات</span>
# </div>
# <div class="izooto-optin--message mt-5">
# <span class="izooto-optin--line-clamp izooto-optin--line-clamp-2">تلقى آخر الأخبار والمستجدات من موقع يلاكورة</span>
# </div>
# </div>
# </div>
# <div class="iz-col">
# <div class="iz-row iz-row--flex-end izooto-optin--ctas-container izooto-optin--ctas-container-for-mob">
# <button class="izooto-optin--cta izooto-optin--cta-later" onclick="CloseDialog();">لاحقا</button>
# <button class="izooto-optin--cta izooto-optin--cta-allow" onclick="OpenDialog()">اشترك</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#         if (Notification.permission !== "granted" && General.GetCookie('DismissNotification') !== 'true') {
#             $('#izmiddle-box').show();
#
#             function OpenDialog() {
#                 window._izq.push(['triggerPrompt']);
#                 $('#izmiddle-box').addClass('hide');
#             }
#             function CloseDialog() {
#                 General.SetCookie('DismissNotification', 'true', 7);
#                 $('#izmiddle-box').addClass('hide');
#             }
#         }
#
#         else {
#             $('#izmiddle-box').hide();
#         }
#     </script>
# <!-- Lazyload -->
# <!--Tracking event for video compagins-->
# <script>
#         $('.goToVideo').click(function () {
#             //ga('send', {
#             //    hitType: 'event',
#             //    eventCategory: 'campaign',
#             //    eventAction: 'play-video',
#             //    eventLabel: 'pepsi-Campaign'
#             //});
#             TrackEvent('campaign', 'play-video', 'pepsi-Campaign');
#
#         });
#         $('#showcase_expandable_btn').hover(function () {
#             //ga('send', {
#             //    hitType: 'event',
#             //    eventCategory: 'campaign',
#             //    eventAction: 'play-video',
#             //    eventLabel: 'pepsi-Campaign'
#             //});
#             TrackEvent('campaign', 'play-video', 'pepsi-Campaign');
#
#
#             console.log("mouse hovered to mo salah showcase ad");
#         });
#         if ('False'=='True') {
#             $('.Mobile-SC').click(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'click-sc-mob',
#                 //    eventLabel: 'Beyti-click-sc-mob'
#                 //});
#                 TrackEvent('campaign', 'click-sc-mob', 'Beyti-click-sc-mob');
#
#             });
#         }
#         else {
#             $('.Desktop_SC').hover(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'hover-desktop-sc',
#                 //    eventLabel: 'Beyti-hover-desktop-sc'
#                 //});
#                 TrackEvent('campaign', 'hover-desktop-sc', 'Beyti-hover-desktop-sc');
#
#
#             });
#             $('.Desktop-OTP').hover(function () {
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'campaign',
#                 //    eventAction: 'hover-desktop-otp',
#                 //    eventLabel: 'Beyti-hover-desktop-otp'
#                 //});
#                 TrackEvent('campaign', 'hover-desktop-otp', 'Beyti-hover-desktop-otp');
#
#
#             });
#         }
#         </script>
# <script>
#             $('body').on('click', '.sp-wi-item a', function () {
#                 // do something
#                 console.log('Speakol Item is clicked');
#                 //ga('send', {
#                 //    hitType: 'event',
#                 //    eventCategory: 'Speakol-Tracking',
#                 //    eventAction: 'Open-Speakol-Link',
#                 //    eventLabel: 'Open-Speakol-Link'
#                 //});
#                 TrackEvent('Speakol-Tracking', 'Open-Speakol-Link', 'Open-Speakol-Link');
#
#             });
#         </script>
# <script>
#            function trackPageView(hashTag) {
#                 var isMobile = 'False';
#                 if (isMobile == "True") {
#                     isMobile = "/mobile/";
#                 }
#                 else {
#                     isMobile = "";
#                 }
#
#                 var curUrl = isMobile + location.pathname + location.search;
#                 if (hashTag != '' && hashTag != undefined) {
#                     curUrl += hashTag;
#                 }
#                 else {
#                     curUrl += location.hash
#                 }
#                 try {
#                     //For google analytics
#                     ga('send', 'pageview', curUrl);
#                     //console.log("go tacking " + curUrl);
#
#                 } catch (ex) {
#                     console.log(ex.message);
#                }
#                trackPageViewGA4(hashTag);
#         }
#         function trackPageViewGA4(hashTag) {
#                 var isMobile = 'False';
#                 if (isMobile == "True") {
#                     isMobile = "/mobile/";
#                 }
#                 else {
#                     isMobile = "";
#                 }
#
#                 var curUrl = isMobile + location.pathname + location.search;
#                 if (hashTag != '' && hashTag != undefined) {
#                     curUrl += hashTag;
#                 }
#                 else {
#                     curUrl += location.hash
#             }
#             curUrl = decodeURIComponent(curUrl);
#                 try {
#                     //For google analytics
#                     ga('send', 'pageview', curUrl);
#                     gtag('event', 'page_view', {
#                         page_location: curUrl,
#                         page_path: curUrl,
#                         send_to: 'G-SS8RTJKBPS'
#                     })
#                     console.log("GA4 track page view:  " + curUrl);
#
#                 } catch (ex) {
#                     console.log(ex.message);
#                 }
#             }
#         </script>
# <script type="application/ld+json">
#         {
#         "@context" : "http://schema.org",
#         "@type" : "Organization",
#         "name" : "Yallakora",
#         "url" : "https://www.yallakora.com/",
#         "logo": "https://www.yallakora.com//Images/Logo/192x192.png?ver=1",
#         "sameAs" : [
#         "https://www.facebook.com/Yallakora/",
#         "https://twitter.com/Yallakoranow",
#         "https://www.youtube.com/channel/UC7N7DXktAhFpRpYb3B6Hnxg",
#         "https://www.instagram.com/yallakoraofficial/"
#         ]
#         }
#     </script>
# <script>(function(){var js = "window['__CF$cv$params']={r:'7e7ce7c61de3800f',m:'.quCbCSBmnyAv0NdBSCQ3KIH0qbiQLe_VoT2pMIuP28-1689538403-0-AYHm94E5uZj9XP2NnNGQaECgv4abN+8iUOxHOUW8D0hO'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script></body>
# </html>

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    championship= soup.find('div', class_= "matchCenterDays")
    print(championship)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:12/17/2022
# <div class="matchCenterDays">
# <div class="daysSlider tab">
# <button class="dayTabLinks" date="6/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="7/31/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>يوليه</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="8/31/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>أغسطس</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="9/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>سبتمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="10/31/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>أكتوبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/18/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/19/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/20/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/21/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/22/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/23/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/24/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/25/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/26/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/27/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/28/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/29/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="11/30/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>نوفمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/1/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/2/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/3/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/4/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/5/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/6/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/7/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/8/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/9/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/10/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/11/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/12/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/13/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/14/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/15/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="12/16/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>ديسمبر</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks active" date="12/17/2022">
# <div class="day">
# <div class="dayCnts">
# <p>
# ...
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/22/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/23/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/24/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/25/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/29/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="4/30/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>أبريل</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/18/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             18
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/19/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             19
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/20/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             20
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/21/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             21
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/22/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             22
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/23/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             23
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/24/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             24
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/25/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             25
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/26/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             26
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/27/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             27
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/28/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             28
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/29/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             29
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/30/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             30
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="5/31/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             31
#                         </p>
# <span>مايو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/1/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             1
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/2/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             2
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/3/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             3
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/4/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             4
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/5/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             5
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/6/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             6
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/7/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             7
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/8/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             8
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/9/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             9
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/10/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             10
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/11/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             11
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sun
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/12/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             12
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Mon
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/13/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             13
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Tue
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/14/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             14
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Wed
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/15/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             15
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Thu
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/16/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             16
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Fri
#                 </div>
# </button>
# <button class="dayTabLinks" date="6/17/2023">
# <div class="day">
# <div class="dayCnts">
# <p>
#                             17
#                         </p>
# <span>يونيو</span>
# </div>
# </div>
# <div class="dayName">
#                     Sat
#                 </div>
# </button>
# </div>
# </div>

# %%
import requests

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    title=soup.div
    print(title)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:12/12/2022
# <div class="sponsorContainer">
# <!-- Sponsor -->
# <script>
#     var AddsenseTimeOut = 5000;
# </script>
# </div>

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    script=soup.script
    print(script)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:12/17/2022
# <script type="text/javascript">
#         var _sf_startpt = (new Date()).getTime()
#     </script>

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    script=soup.script.text
    print(script)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:12/17/2022
#
#         var _sf_startpt = (new Date()).getTime()

# %%
date=input("Please enter a date in the following formAT MM/DD/YYYY:")
page= requests.get(f"https://www.yallakora.com/match-center/%D9%85%D8%B1%D9%83%D8%B2-%D8%A7%D9%84%D9%85%D8%A8%D8%A7%D8%B1%D9%8A%D8%A7%D8%AA?date={date}#")
def main(page):
    src=page.content
    soup= BeautifulSoup(src,"lxml")
    video=soup.find('div', class_="carousel_card_gradient")
    print(video)

main(page)
# Out:
# Please enter a date in the following formAT MM/DD/YYYY:7/17/2023
# None
