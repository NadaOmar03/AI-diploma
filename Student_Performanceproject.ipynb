# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
summary=df.describe()
summary
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 127

# %%
df.drop_duplicates()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
a = "Extracurricular Activities"

for no , i in enumerate(df.columns):
    if i != a :
        sns.histplot(data=df,x=i)
        plt.show()

# %%
for i in ['Hours Studied', 'Sleep Hours','Sample Question Papers Practiced']:
    sns.countplot(x=i,hue="Extracurricular Activities",data=df)
    plt.legend(bbox_to_anchor = (1.05,1))
    plt.show()

# %%
plt.scatter(df["Hours Studied"],df["Performance Index"])


plt.xlabel("Hours studied")
plt.ylabel("Performance Index")
plt.title("Hours Studied VS Performance Index")
plt.show()

# %%
sns.barplot(x="Extracurricular Activities", y="Performance Index",data=df)

plt.xlabel("Extracurricular Activities")
plt.ylabel("Performance Index")
plt.title("Performance Index by Extracurricular Activities")
plt.show()

# %%
# %matplotlib inline
plt.xlabel('Extracurricular Activities')
plt.ylabel('')
plt.scatter(df['Extracurricular Activities'],color='red',marker='+')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2c16f360af58> in <cell line: 4>()
#       2 plt.xlabel('Extracurricular Activities')
#       3 plt.ylabel('')
# ----> 4 plt.scatter(df['Extracurricular Activities'],color='red',marker='+')
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
# %matplotlib inline
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.scatter(df['Hours Studied'],df['Performance Index'],color='red',marker='.')

# %%
# Group the data by extracurricular activities and calculate the mean performance
grouped_data = df.groupby('Extracurricular Activities')['Performance Index'].mean()

# Create a bar plot
plt.bar(x=grouped_data.index, y=grouped_data.value)
plt.xlabel('Extracurricular Activities')
plt.ylabel('Mean Performance Index')
plt.title('Impact of Extracurricular Activities on Performance')
plt.show()

# %%
# %matplotlib inline
plt.xlabel('Hours Studied')
plt.ylabel('Performance Index')
plt.scatter(df['Hours Studied'],df['Performance Index'],color='red',marker='.')

# %%
# Create a heat map
sns.heatmap(df)

# Customize the heat map
plt.title('Heat Map')
plt.xlabel('Columns')
plt.ylabel('Rows')

# Display the heat map
plt.show()

# %%
# Create a DataFrame with two columns
data = pd.df({'Sample Question Papers Practiced': Sample Question Papers Practiced,
                     'Performance Index': Performance Index})

# Create a violin plot
sns.violinplot(x='Category', y='Value', data=data)

# Display the plot
plt.show()
